# %%
import pandas as pd
import numpy as np
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, InputLayer
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, AveragePooling2D
from keras.optimizers import Adam
import cv2
from scipy.fft import fft2, ifft2, fftshift, ifftshift
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16
import scipy.fftpack as fp
from skimage.io import imread
from tensorflow.keras.metrics import AUC, Precision, Recall
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# %%
tp = pd.read_csv('tp_list.txt', header=None)
au = pd.read_csv('au_list.txt', header=None)
file_path_au = "C:\\Users\\jakub\\Desktop\\Au"
file_path_tp = "C:\\Users\\jakub\\Desktop\\Tp"
au[0] = file_path_au + "\\" + au[0]
tp[0] = file_path_tp + "\\" + tp[0]
au.columns = ['file_path']
tp.columns = ['file_path']
au['type'] = 'Authentic'
tp['type'] = 'Forged'

# %%
im_df = pd.concat([au, tp], ignore_index=True)

# %%
def preprocess_image(image_path, output_size=(224, 224)):
    # Wczytanie obrazu w skali szarości i kolorowym (RGB)
    img_gray = cv2.imread(image_path, 0)  # Wczytanie w skali szarości
    img_gray = cv2.resize(img_gray, output_size)  # Skalowanie do (224, 224) 

    # Przetwarzanie obrazu w skali szarości
    dft = cv2.dft(np.float32(img_gray), flags=cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)

    rows, cols = img_gray.shape    
    crow, ccol = int(rows / 2), int(cols / 2)
    mask = np.ones((rows, cols, 2), np.uint8)
    r = 64  # Rozmiar maski - określa odcięcie HPF
    center = [crow, ccol]
    x, y = np.ogrid[:rows, :cols]
    mask_area = (x - center[0]) ** 2 + (y - center[1]) ** 2 <= r*r
    mask[mask_area] = 0
    fshift = dft_shift * mask

    f_ishift = np.fft.ifftshift(fshift)
    img_back = cv2.idft(f_ishift)
    img_back = cv2.magnitude(img_back[:, :, 0], img_back[:, :, 1])

    # Normalizacja do zakresu [0, 255]
    img_normalized = cv2.normalize(img_back, None, 0, 255, cv2.NORM_MINMAX)
    img_normalized = np.uint8(img_normalized)  # Konwersja na typ uint8
    return img_normalized

# %%
def save_image():
    labels = []
    imgs = []
    
    for i in range(len(im_df)):
        labels.append(im_df['type'][i]) 
        img_normalized = preprocess_image(im_df['file_path'][i]) 
        imgs.append(img_normalized)
    
    return labels, imgs

# %%
#odzyskiwanie ramu
del tp
del au
del file_path_au
del file_path_tp

# %%
labels, imgs = save_image()

# %%
#odzyskiwanie ramu
del im_df

# %%
u = list(np.unique(labels)) #lsita unikalnych wartości w labels (red, green, other)

ilabels = np.asarray([u.index(l) for l in labels]) #utworzenie nowej listy zawierającyh wartości unikalne w postaci liczb, a nie tekstu

# %%
#odzyskiwanie ramu
del u
del labels

# %% [markdown]
# Kodu niżej nie uruchmiać jeśli nie ma się 32 GB RAMU, bo freezuje komputer

# %%
X = np.stack(imgs) / 255.0 - 0.5 #połączenie wszystkich osobnych list zawarty w imgs w jedną podzielenie wartości przez 255, ay otrzymać wartości od 0 do 1 i pomniejszenie wartości o 0.5 i otrzymanie od -0.5 do 0.5

# %%
del imgs

# %%
X_train, X_test, y_train, y_test = train_test_split(X, ilabels, test_size=0.2, shuffle=True, random_state=42) #podzielenie danych na treningowe i testowe, jak wyżej

# %%
del X
del ilabels

# %%
# Tworzenie modelu Sequential
input_shape = (224, 224, 1)

# Define the CNN model
model = Sequential([
        # Input layer with Conv2D
        Conv2D(filters=25, kernel_size=(3, 3), activation='relu', input_shape=input_shape, name='conv2d'),

        # MaxPooling 
        MaxPooling2D(pool_size=(2, 2), strides=(1, 1),  padding='same', name='max_pooling2d'),

        # Flatten layer
        Flatten(name='flatten'),

        # Fully connected Dense layers
        Dense(100, activation='relu', name='dense'),
        Dense(100, activation='relu', name='dense_1'),
        Dense(100, activation='relu', name='dense_2'),

        # Output layer
        Dense(1, activation='sigmoid', name='dense_3')
])

# Kompilacja modelu z dodatkowymi metrykami
model.compile(loss='binary_crossentropy', 
              optimizer=Adam(learning_rate=1e-3), 
              metrics=['accuracy', AUC(name="AUC"), Precision(name="Precision"), Recall(name="Recall"), keras.metrics.TruePositives(name="TP"), keras.metrics.TrueNegatives(name="TN")])
            
# Podsumowanie modelu
model.summary()
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 222, 222, 16)   │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 111, 111, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 109, 109, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 52, 52, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 26, 26, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 10, 10, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       819,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,211,906 (4.62 MB)
#  Trainable params: 1,211,906 (4.62 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
h = model.fit(X_train, y_train, batch_size=32, epochs=100, verbose=2, validation_data=(X_test, y_test), callbacks=EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=False ))
# Out:
# Epoch 1/100
# 21/21 - 12s - 590ms/step - accuracy: 0.4657 - auc_1: 0.4661 - loss: 0.6960 - precision_1: 0.4657 - recall_1: 0.4657 - val_accuracy: 0.5000 - val_auc_1: 0.5667 - val_loss: 0.6926 - val_precision_1: 0.5000 - val_recall_1: 0.5000
# Epoch 2/100
# 21/21 - 9s - 406ms/step - accuracy: 0.5090 - auc_1: 0.5114 - loss: 0.6928 - precision_1: 0.5090 - recall_1: 0.5090 - val_accuracy: 0.6818 - val_auc_1: 0.6188 - val_loss: 0.6915 - val_precision_1: 0.6818 - val_recall_1: 0.6818
# Epoch 3/100
# 21/21 - 8s - 400ms/step - accuracy: 0.5254 - auc_1: 0.5236 - loss: 0.6928 - precision_1: 0.5254 - recall_1: 0.5254 - val_accuracy: 0.6545 - val_auc_1: 0.6815 - val_loss: 0.6901 - val_precision_1: 0.6545 - val_recall_1: 0.6545
# Epoch 4/100
# 21/21 - 10s - 482ms/step - accuracy: 0.6507 - auc_1: 0.6605 - loss: 0.6882 - precision_1: 0.6507 - recall_1: 0.6507 - val_accuracy: 0.6273 - val_auc_1: 0.6650 - val_loss: 0.6821 - val_precision_1: 0.6273 - val_recall_1: 0.6273
# Epoch 5/100
# 21/21 - 10s - 454ms/step - accuracy: 0.6164 - auc_1: 0.6303 - loss: 0.6784 - precision_1: 0.6164 - recall_1: 0.6164 - val_accuracy: 0.6485 - val_auc_1: 0.6940 - val_loss: 0.6571 - val_precision_1: 0.6485 - val_recall_1: 0.6485
# Epoch 6/100
# 21/21 - 10s - 486ms/step - accuracy: 0.6090 - auc_1: 0.6497 - loss: 0.6661 - precision_1: 0.6090 - recall_1: 0.6090 - val_accuracy: 0.5818 - val_auc_1: 0.6354 - val_loss: 0.6601 - val_precision_1: 0.5818 - val_recall_1: 0.5818
# Epoch 7/100
# 21/21 - 9s - 443ms/step - accuracy: 0.6045 - auc_1: 0.6532 - loss: 0.6626 - precision_1: 0.6045 - recall_1: 0.6045 - val_accuracy: 0.6636 - val_auc_1: 0.7048 - val_loss: 0.6339 - val_precision_1: 0.6636 - val_recall_1: 0.6636
# Epoch 8/100
# 21/21 - 9s - 407ms/step - accuracy: 0.6642 - auc_1: 0.7031 - loss: 0.6337 - precision_1: 0.6642 - recall_1: 0.6642 - val_accuracy: 0.6818 - val_auc_1: 0.7254 - val_loss: 0.6198 - val_precision_1: 0.6818 - val_recall_1: 0.6818
# Epoch 9/100
# 21/21 - 9s - 411ms/step - accuracy: 0.6776 - auc_1: 0.7253 - loss: 0.6220 - precision_1: 0.6776 - recall_1: 0.6776 - val_accuracy: 0.6758 - val_auc_1: 0.7300 - val_loss: 0.6146 - val_precision_1: 0.6758 - val_recall_1: 0.6758
# Epoch 10/100
# 21/21 - 10s - 498ms/step - accuracy: 0.6925 - auc_1: 0.7282 - loss: 0.6168 - precision_1: 0.6925 - recall_1: 0.6925 - val_accuracy: 0.6909 - val_auc_1: 0.7335 - val_loss: 0.6105 - val_precision_1: 0.6909 - val_recall_1: 0.6909
# Epoch 11/100
# 21/21 - 10s - 474ms/step - accuracy: 0.6761 - auc_1: 0.7316 - loss: 0.6120 - precision_1: 0.6761 - recall_1: 0.6761 - val_accuracy: 0.6667 - val_auc_1: 0.7175 - val_loss: 0.6213 - val_precision_1: 0.6667 - val_recall_1: 0.6667
# Epoch 12/100
# 21/21 - 8s - 368ms/step - accuracy: 0.7104 - auc_1: 0.7508 - loss: 0.5984 - precision_1: 0.7104 - recall_1: 0.7104 - val_accuracy: 0.6970 - val_auc_1: 0.7506 - val_loss: 0.5940 - val_precision_1: 0.6970 - val_recall_1: 0.6970
# Epoch 13/100
# 21/21 - 8s - 359ms/step - accuracy: 0.7060 - auc_1: 0.7713 - loss: 0.5794 - precision_1: 0.7060 - recall_1: 0.7060 - val_accuracy: 0.7030 - val_auc_1: 0.7562 - val_loss: 0.5925 - val_precision_1: 0.7030 - val_recall_1: 0.7030
# Epoch 14/100
# 21/21 - 11s - 535ms/step - accuracy: 0.7224 - auc_1: 0.7727 - loss: 0.5744 - precision_1: 0.7224 - recall_1: 0.7224 - val_accuracy: 0.6970 - val_auc_1: 0.7615 - val_loss: 0.5802 - val_precision_1: 0.6970 - val_recall_1: 0.6970
# Epoch 15/100
# 21/21 - 8s - 398ms/step - accuracy: 0.7149 - auc_1: 0.7711 - loss: 0.5740 - precision_1: 0.7149 - recall_1: 0.7149 - val_accuracy: 0.7212 - val_auc_1: 0.7608 - val_loss: 0.5903 - val_precision_1: 0.7212 - val_recall_1: 0.7212
# Epoch 16/100
# 21/21 - 11s - 511ms/step - accuracy: 0.7209 - auc_1: 0.7945 - loss: 0.5522 - precision_1: 0.7209 - recall_1: 0.7209 - val_accuracy: 0.7273 - val_auc_1: 0.7801 - val_loss: 0.5711 - val_precision_1: 0.7273 - val_recall_1: 0.7273
# Epoch 17/100
# 21/21 - 11s - 503ms/step - accuracy: 0.7299 - auc_1: 0.8108 - loss: 0.5339 - precision_1: 0.7299 - recall_1: 0.7299 - val_accuracy: 0.7212 - val_auc_1: 0.7824 - val_loss: 0.5624 - val_precision_1: 0.7212 - val_recall_1: 0.7212
# Epoch 18/100
# 21/21 - 10s - 453ms/step - accuracy: 0.7507 - auc_1: 0.8234 - loss: 0.5166 - precision_1: 0.7507 - recall_1: 0.7507 - val_accuracy: 0.7182 - val_auc_1: 0.7885 - val_loss: 0.5578 - val_precision_1: 0.7182 - val_recall_1: 0.7182
# Epoch 19/100
# 21/21 - 9s - 430ms/step - accuracy: 0.7373 - auc_1: 0.8200 - loss: 0.5189 - precision_1: 0.7373 - recall_1: 0.7373 - val_accuracy: 0.7273 - val_auc_1: 0.7980 - val_loss: 0.5428 - val_precision_1: 0.7273 - val_recall_1: 0.7273
# Epoch 20/100
# 21/21 - 8s - 364ms/step - accuracy: 0.7552 - auc_1: 0.8377 - loss: 0.4969 - precision_1: 0.7552 - recall_1: 0.7552 - val_accuracy: 0.7212 - val_auc_1: 0.7858 - val_loss: 0.5679 - val_precision_1: 0.7212 - val_recall_1: 0.7212
# Epoch 21/100
# 21/21 - 9s - 418ms/step - accuracy: 0.7731 - auc_1: 0.8473 - loss: 0.4853 - precision_1: 0.7731 - recall_1: 0.7731 - val_accuracy: 0.7333 - val_auc_1: 0.8045 - val_loss: 0.5355 - val_precision_1: 0.7333 - val_recall_1: 0.7333
# Epoch 22/100
# 21/21 - 9s - 412ms/step - accuracy: 0.7776 - auc_1: 0.8551 - loss: 0.4742 - precision_1: 0.7776 - recall_1: 0.7776 - val_accuracy: 0.7121 - val_auc_1: 0.7831 - val_loss: 0.5882 - val_precision_1: 0.7121 - val_recall_1: 0.7121
# Epoch 23/100
# 21/21 - 8s - 397ms/step - accuracy: 0.7791 - auc_1: 0.8697 - loss: 0.4543 - precision_1: 0.7791 - recall_1: 0.7791 - val_accuracy: 0.7303 - val_auc_1: 0.8007 - val_loss: 0.5494 - val_precision_1: 0.7303 - val_recall_1: 0.7303
# Epoch 24/100
# 21/21 - 8s - 367ms/step - accuracy: 0.7866 - auc_1: 0.8799 - loss: 0.4366 - precision_1: 0.7866 - recall_1: 0.7866 - val_accuracy: 0.7303 - val_auc_1: 0.7959 - val_loss: 0.5613 - val_precision_1: 0.7303 - val_recall_1: 0.7303
# Epoch 25/100
# 21/21 - 6s - 299ms/step - accuracy: 0.7896 - auc_1: 0.8767 - loss: 0.4347 - precision_1: 0.7896 - recall_1: 0.7896 - val_accuracy: 0.7152 - val_auc_1: 0.7901 - val_loss: 0.5814 - val_precision_1: 0.7152 - val_recall_1: 0.7152
# Epoch 26/100
# 21/21 - 6s - 294ms/step - accuracy: 0.8134 - auc_1: 0.8891 - loss: 0.4254 - precision_1: 0.8134 - recall_1: 0.8134 - val_accuracy: 0.7333 - val_auc_1: 0.7972 - val_loss: 0.5616 - val_precision_1: 0.7333 - val_recall_1: 0.7333
# Epoch 27/100
# 21/21 - 6s - 303ms/step - accuracy: 0.8358 - auc_1: 0.9111 - loss: 0.3795 - precision_1: 0.8358 - recall_1: 0.8358 - val_accuracy: 0.7364 - val_auc_1: 0.8010 - val_loss: 0.5741 - val_precision_1: 0.7364 - val_recall_1: 0.7364
# Epoch 28/100
# 21/21 - 8s - 368ms/step - accuracy: 0.8269 - auc_1: 0.9113 - loss: 0.3790 - precision_1: 0.8269 - recall_1: 0.8269 - val_accuracy: 0.7182 - val_auc_1: 0.7979 - val_loss: 0.6040 - val_precision_1: 0.7182 - val_recall_1: 0.7182
# Epoch 29/100
# 21/21 - 8s - 368ms/step - accuracy: 0.8313 - auc_1: 0.9190 - loss: 0.3654 - precision_1: 0.8313 - recall_1: 0.8313 - val_accuracy: 0.7212 - val_auc_1: 0.7961 - val_loss: 0.6064 - val_precision_1: 0.7212 - val_recall_1: 0.7212
# Epoch 30/100
# 21/21 - 7s - 346ms/step - accuracy: 0.8612 - auc_1: 0.9332 - loss: 0.3369 - precision_1: 0.8612 - recall_1: 0.8612 - val_accuracy: 0.7455 - val_auc_1: 0.8054 - val_loss: 0.6008 - val_precision_1: 0.7455 - val_recall_1: 0.7455
# Epoch 31/100
# 21/21 - 8s - 362ms/step - accuracy: 0.8463 - auc_1: 0.9313 - loss: 0.3353 - precision_1: 0.8463 - recall_1: 0.8463 - val_accuracy: 0.7212 - val_auc_1: 0.7960 - val_loss: 0.6177 - val_precision_1: 0.7212 - val_recall_1: 0.7212
# Epoch 32/100
# 21/21 - 8s - 398ms/step - accuracy: 0.8507 - auc_1: 0.9398 - loss: 0.3168 - precision_1: 0.8507 - recall_1: 0.8507 - val_accuracy: 0.7424 - val_auc_1: 0.7988 - val_loss: 0.6412 - val_precision_1: 0.7424 - val_recall_1: 0.7424
# Epoch 33/100
# 21/21 - 7s - 348ms/step - accuracy: 0.8657 - auc_1: 0.9481 - loss: 0.2986 - precision_1: 0.8657 - recall_1: 0.8657 - val_accuracy: 0.7242 - val_auc_1: 0.8023 - val_loss: 0.6374 - val_precision_1: 0.7242 - val_recall_1: 0.7242
# Epoch 34/100
# 21/21 - 8s - 399ms/step - accuracy: 0.8731 - auc_1: 0.9475 - loss: 0.2969 - precision_1: 0.8731 - recall_1: 0.8731 - val_accuracy: 0.7485 - val_auc_1: 0.7956 - val_loss: 0.7198 - val_precision_1: 0.7485 - val_recall_1: 0.7485
# Epoch 35/100
# 21/21 - 8s - 381ms/step - accuracy: 0.8806 - auc_1: 0.9564 - loss: 0.2731 - precision_1: 0.8806 - recall_1: 0.8806 - val_accuracy: 0.7303 - val_auc_1: 0.7951 - val_loss: 0.6661 - val_precision_1: 0.7303 - val_recall_1: 0.7303
# Epoch 36/100
# 21/21 - 8s - 402ms/step - accuracy: 0.8910 - auc_1: 0.9589 - loss: 0.2640 - precision_1: 0.8910 - recall_1: 0.8910 - val_accuracy: 0.7545 - val_auc_1: 0.8075 - val_loss: 0.6630 - val_precision_1: 0.7545 - val_recall_1: 0.7545
# Epoch 37/100
# 21/21 - 9s - 433ms/step - accuracy: 0.9075 - auc_1: 0.9687 - loss: 0.2350 - precision_1: 0.9075 - recall_1: 0.9075 - val_accuracy: 0.7485 - val_auc_1: 0.8008 - val_loss: 0.7563 - val_precision_1: 0.7485 - val_recall_1: 0.7485
# Epoch 38/100
# 21/21 - 9s - 417ms/step - accuracy: 0.9060 - auc_1: 0.9755 - loss: 0.2090 - precision_1: 0.9060 - recall_1: 0.9060 - val_accuracy: 0.7455 - val_auc_1: 0.8091 - val_loss: 0.7613 - val_precision_1: 0.7455 - val_recall_1: 0.7455
# Epoch 39/100
# 21/21 - 8s - 397ms/step - accuracy: 0.9015 - auc_1: 0.9687 - loss: 0.2270 - precision_1: 0.9015 - recall_1: 0.9015 - val_accuracy: 0.7424 - val_auc_1: 0.8082 - val_loss: 0.7521 - val_precision_1: 0.7424 - val_recall_1: 0.7424
# Epoch 40/100
# 21/21 - 10s - 482ms/step - accuracy: 0.8925 - auc_1: 0.9657 - loss: 0.2376 - precision_1: 0.8925 - recall_1: 0.8925 - val_accuracy: 0.7455 - val_auc_1: 0.7998 - val_loss: 0.7143 - val_precision_1: 0.7455 - val_recall_1: 0.7455
# Epoch 41/100
# 21/21 - 8s - 396ms/step - accuracy: 0.9284 - auc_1: 0.9815 - loss: 0.1881 - precision_1: 0.9284 - recall_1: 0.9284 - val_accuracy: 0.7152 - val_auc_1: 0.8049 - val_loss: 0.7732 - val_precision_1: 0.7152 - val_recall_1: 0.7152

# %%
# Tworzenie DataFrame z historii trenowania
history_df = pd.DataFrame(h.history)

# Obliczanie przedziałów ufności (np. 95%)
confidence_interval = 0.95
ci_bounds = int((1 - confidence_interval) * 100 / 2)

# Funkcja do obliczania przedziału ufności
def compute_confidence_interval(values):
    mean = np.mean(values)
    std = np.std(values)
    ci_range = std * 1.96  # 95% przedział ufności
    return mean - ci_range, mean + ci_range

# Tworzenie wykresów
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Wykres dla loss
axes[0].plot(history_df['loss'], label='Loss', color='green', marker='o')
axes[0].plot(history_df['val_loss'], label='Loss', color='red', marker='o')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].set_ylim(0, max(history_df[['loss', 'val_loss']].max()) + 0.1)  # Skala od 0

# Wykres dla accuracy
axes[1].plot(history_df['accuracy'], label='Accuracy', color='green', marker='o')
axes[1].plot(history_df['val_accuracy'], label='Accuracy', color='red', marker='o')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].set_ylim(0, max(history_df[['accuracy', 'val_accuracy']].max()) + 0.1)  # Skala od 0
# Zapis do pliku SVG
plt.tight_layout()
plt.savefig('training_history_with_ci.svg', format='svg')
plt.show()

print("Training history with confidence intervals saved as training_history_with_ci.svg")
# Out:
# Training history with confidence intervals saved as training_history_with_ci.svg

# %%
history_df.to_csv('fft_gray.csv', index=False)

# %%
history_df
# Out:
#     accuracy     auc_1      loss  precision_1  recall_1  val_accuracy  \
# 0   0.465672  0.466086  0.695960     0.465672  0.465672      0.500000
# 1   0.508955  0.511360  0.692828     0.508955  0.508955      0.681818
# 2   0.525373  0.523599  0.692754     0.525373  0.525373      0.654545
# 3   0.650746  0.660549  0.688221     0.650746  0.650746      0.627273
# 4   0.616418  0.630298  0.678432     0.616418  0.616418      0.648485
# 5   0.608955  0.649705  0.666065     0.608955  0.608955      0.581818
# 6   0.604478  0.653247  0.662638     0.604478  0.604478      0.663636
# 7   0.664179  0.703117  0.633729     0.664179  0.664179      0.681818
# 8   0.677612  0.725281  0.621960     0.677612  0.677612      0.675758
# 9   0.692537  0.728177  0.616818     0.692537  0.692537      0.690909
# 10  0.676119  0.731619  0.611958     0.676119  0.676119      0.666667
# 11  0.710448  0.750813  0.598428     0.710448  0.710448      0.696970
# 12  0.705970  0.771344  0.579379     0.705970  0.705970      0.703030
# 13  0.722388  0.772744  0.574361     0.722388  0.722388      0.696970
# 14  0.714925  0.771065  0.574011     0.714925  0.714925      0.721212
# 15  0.720896  0.794490  0.552232     0.720896  0.720896      0.727273
# 16  0.729851  0.810810  0.533929     0.729851  0.729851      0.721212
# 17  0.750746  0.823354  0.516580     0.750746  0.750746      0.718182
# 18  0.737313  0.820038  0.518946     0.737313  0.737313      0.727273
# 19  0.755224  0.837658  0.496945     0.755224  0.755224      0.721212
# 20  0.773134  0.847272  0.485347     0.773134  0.773134      0.733333
# 21  0.777612  0.855146  0.474247     0.777612  0.777612      0.712121
# 22  0.779104  0.869664  0.454263     0.779104  0.779104      0.730303
# 23  0.786567  0.879871  0.436572     0.786567  0.786567      0.730303
# 24  0.789552  0.876747  0.434694     0.789552  0.789552      0.715151
# 25  0.813433  0.889143  0.425384     0.813433  0.813433      0.733333
# 26  0.835821  0.911083  0.379477     0.835821  0.835821      0.736364
# 27  0.826866  0.911283  0.379019     0.826866  0.826866      0.718182
# 28  0.831343  0.919042  0.365379     0.831343  0.831343      0.721212
# 29  0.861194  0.933157  0.336871     0.861194  0.861194      0.745455
# 30  0.846269  0.931312  0.335308     0.846269  0.846269      0.721212
# 31  0.850746  0.939811  0.316797     0.850746  0.850746      0.742424
# 32  0.865672  0.948133  0.298565     0.865672  0.865672      0.724242
# 33  0.873134  0.947495  0.296852     0.873134  0.873134      0.748485
# 34  0.880597  0.956384  0.273052     0.880597  0.880597      0.730303
# 35  0.891045  0.958876  0.264039     0.891045  0.891045      0.754545
# 36  0.907463  0.968704  0.235030     0.907463  0.907463      0.748485
# 37  0.905970  0.975500  0.208961     0.905970  0.905970      0.745455
# 38  0.901493  0.968708  0.226992     0.901493  0.901493      0.742424
# 39  0.892537  0.965709  0.237617     0.892537  0.892537      0.745455
# 40  0.928358  0.981527  0.188077     0.928358  0.928358      0.715151
#
#     val_auc_1  val_loss  val_precision_1  val_recall_1
# 0    0.566667  0.692626         0.500000      0.500000
# 1    0.618802  0.691528         0.681818      0.681818
# 2    0.681543  0.690140         0.654545      0.654545
# 3    0.665000  0.682053         0.627273      0.627273
# 4    0.694045  0.657099         0.648485      0.648485
# 5    0.635386  0.660092         0.581818      0.581818
# 6    0.704793  0.633945         0.663636      0.663636
# 7    0.725409  0.619806         0.681818      0.681818
# 8    0.730018  0.614605         0.675758      0.675758
# 9    0.733494  0.610467         0.690909      0.690909
# 10   0.717452  0.621343         0.666667      0.666667
# 11   0.750592  0.594033         0.696970      0.696970
# 12   0.756152  0.592468         0.703030      0.703030
# 13   0.761455  0.580154         0.696970      0.696970
# 14   0.760776  0.590323         0.721212      0.721212
# 15   0.780101  0.571115         0.727273      0.727273
# 16   0.782433  0.562417         0.721212      0.721212
# 17   0.788522  0.557830         0.718182      0.718182
# 18   0.798012  0.542797         0.727273      0.727273
# 19   0.785817  0.567854         0.721212      0.721212
# 20   0.804481  0.535539         0.733333      0.733333
# 21   0.783072  0.588228         0.712121      0.712121
# 22   0.800739  0.549382         0.730303      0.730303
# 23   0.795932  0.561256         0.730303      0.730303
# 24   0.790073  0.581365         0.715151      0.715151
# 25   0.797218  0.561615         0.733333      0.733333
# 26   0.801047  0.574073         0.736364      0.736364
# 27   0.797929  0.604050         0.718182      0.718182
# 28   0.796065  0.606434         0.721212      0.721212
# 29   0.805381  0.600816         0.745455      0.745455
# 30   0.796010  0.617712         0.721212      0.721212
# 31   0.798834  0.641168         0.742424      0.742424
# 32   0.802268  0.637427         0.724242      0.724242
# 33   0.795574  0.719833         0.748485      0.748485
# 34   0.795124  0.666070         0.730303      0.730303
# 35   0.807498  0.662995         0.754545      0.754545
# 36   0.800794  0.756273         0.748485      0.748485
# 37   0.809054  0.761336         0.745455      0.745455
# 38   0.808182  0.752114         0.742424      0.742424
# 39   0.799826  0.714315         0.745455      0.745455
# 40   0.804876  0.773176         0.715151      0.715151

# %%
# Ścieżki do obrazów
image_path1 = 'F:\\github\\CASIA2.0_revised\\CASIA2.0_revised\\Au\\Au_art_00011.jpg'  # Zamień na właściwą ścieżkę do obrazu
image_path2 = 'F:\\github\\CASIA2.0_revised\\CASIA2.0_revised\\Tp\\Tp_D_CNN_S_N_art00011_art00014_11841.jpg'  # Zamień na właściwą ścieżkę do obrazu

# Przetwarzanie obrazów
processed_image1 = preprocess_image(image_path1)
processed_image2 = preprocess_image(image_path2)

# Wyświetlanie obrazów
plt.figure(figsize=(10, 5))

# Obraz 1
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(processed_image1, cv2.COLOR_BGR2RGB))
plt.title('Processed authentic image')
plt.axis('off')

# Obraz 2
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(processed_image2, cv2.COLOR_BGR2RGB))
plt.title('Processed forged image')
plt.axis('off')

plt.tight_layout()
plt.show()
